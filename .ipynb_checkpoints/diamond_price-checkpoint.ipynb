# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = r"E:\coding\CSV\diamonds.csv"
df = pd.read_csv(path)

#Dropping dimentionless diamonds
df = df.drop(df[df["x"]==0].index)
df = df.drop(df[df["y"]==0].index)
df = df.drop(df[df["z"]==0].index)
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53920 rows x 11 columns]

# %%
df.rename(columns={"x": "length(mm)", "y": "width(mm)", "z": "depth(mm)"}, inplace=True)
df.drop(columns=("Unnamed: 0"), inplace=True)
df
# Out:
#        carat        cut color clarity  depth  table  price  length(mm)  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326        3.95
# 1       0.21    Premium     E     SI1   59.8   61.0    326        3.89
# 2       0.23       Good     E     VS1   56.9   65.0    327        4.05
# 3       0.29    Premium     I     VS2   62.4   58.0    334        4.20
# 4       0.31       Good     J     SI2   63.3   58.0    335        4.34
# ...      ...        ...   ...     ...    ...    ...    ...         ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757        5.75
# 53936   0.72       Good     D     SI1   63.1   55.0   2757        5.69
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757        5.66
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757        6.15
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757        5.83
#
#        width(mm)  depth(mm)
# 0           3.98       2.43
# 1           3.84       2.31
# 2           4.07       2.31
# 3           4.23       2.63
# 4           4.35       2.75
# ...          ...        ...
# 53935       5.76       3.50
# 53936       5.75       3.61
# 53937       5.68       3.56
# 53938       6.12       3.74
# 53939       5.87       3.64
#
# [53920 rows x 10 columns]

# %%
df.dtypes
# Out:
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# length(mm)    float64
# width(mm)     float64
# depth(mm)     float64
# dtype: object

# %%
df["cut"].value_counts()
# Out:
# cut
# Ideal        21548
# Premium      13780
# Very Good    12081
# Good          4902
# Fair          1609
# Name: count, dtype: int64

# %%
sns.violinplot( x = "cut",y = "price", data=df)
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
df["cut"].value_counts().plot(kind="bar", xlabel = "cut", ylabel = "quantity",  figsize=(16,8))
# Out:
# <Axes: xlabel='cut', ylabel='quantity'>

# %%
df["color"].value_counts()
# Out:
# color
# G    11284
# E     9797
# F     9538
# H     8298
# D     6774
# I     5421
# J     2808
# Name: count, dtype: int64

# %%
sns.violinplot( x = "color",y = "price", data=df)
# Out:
# <Axes: xlabel='color', ylabel='price'>

# %%
df["color"].value_counts().plot(kind="bar", xlabel = "color", ylabel = "quantity",  figsize=(16,8))
# Out:
# <Axes: xlabel='color', ylabel='quantity'>

# %%
df["clarity"].value_counts()
# Out:
# clarity
# SI1     13063
# VS2     12254
# SI2      9185
# VS1      8170
# VVS2     5066
# VVS1     3654
# IF       1790
# I1        738
# Name: count, dtype: int64

# %%
df["clarity"].value_counts().plot(kind="bar", xlabel = "clarity", ylabel = "quantity",  figsize=(16,8))
# Out:
# <Axes: xlabel='clarity', ylabel='quantity'>

# %%
sns.violinplot( x = "clarity",y = "price", data=df)
# Out:
# <Axes: xlabel='clarity', ylabel='price'>

# %% [markdown]
# ## method to convert object column to integers column

# %%
obj = (df.dtypes == "object")
obj_cols = obj[obj].index

obj_cols
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %% [markdown]
# ### method 1

# %%
# df["cut"] = pd.factorize(df.cut)[0]
# df

# %% [markdown]
# ### method 2

# %%
# from sklearn.preprocessing import OneHotEncoder, LabelEncoder
# label_encoder = LabelEncoder()

# df["clarity"] = label_encoder.fit_transform(df.clarity)
# df

# %%
# for col in obj_cols:
#     df[col] = label_encoder.fit_transform(df[col])

# df.head()

# %%
df["cut"].value_counts()
# Out:
# cut
# Ideal        21548
# Premium      13780
# Very Good    12081
# Good          4902
# Fair          1609
# Name: count, dtype: int64

# %%
df["cut"] = df.cut.replace({"Premium":1, "Ideal":2, "Very Good": 3, "Good": 4, "Fair": 5})
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3616\4199614132.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["cut"] = df.cut.replace({"Premium":1, "Ideal":2, "Very Good": 3, "Good": 4, "Fair": 5})
#        carat  cut color clarity  depth  table  price  length(mm)  width(mm)  \
# 0       0.23    2     E     SI2   61.5   55.0    326        3.95       3.98
# 1       0.21    1     E     SI1   59.8   61.0    326        3.89       3.84
# 2       0.23    4     E     VS1   56.9   65.0    327        4.05       4.07
# 3       0.29    1     I     VS2   62.4   58.0    334        4.20       4.23
# 4       0.31    4     J     SI2   63.3   58.0    335        4.34       4.35
# ...      ...  ...   ...     ...    ...    ...    ...         ...        ...
# 53935   0.72    2     D     SI1   60.8   57.0   2757        5.75       5.76
# 53936   0.72    4     D     SI1   63.1   55.0   2757        5.69       5.75
# 53937   0.70    3     D     SI1   62.8   60.0   2757        5.66       5.68
# 53938   0.86    1     H     SI2   61.0   58.0   2757        6.15       6.12
# 53939   0.75    2     D     SI2   62.2   55.0   2757        5.83       5.87
#
#        depth(mm)
# 0           2.43
# 1           2.31
# 2           2.31
# 3           2.63
# 4           2.75
# ...          ...
# 53935       3.50
# 53936       3.61
# 53937       3.56
# 53938       3.74
# 53939       3.64
#
# [53920 rows x 10 columns]

# %%
df["clarity"].value_counts()
# Out:
# clarity
# SI1     13063
# VS2     12254
# SI2      9185
# VS1      8170
# VVS2     5066
# VVS1     3654
# IF       1790
# I1        738
# Name: count, dtype: int64

# %%
df['clarity'] = df.clarity.replace({"I1": 8, "SI2": 7, "SI1": 6, "VS2": 5, "VS1": 4, "VVS2": 3, "VVS1": 2, "IF": 1})    # from worst to best
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3616\4079104182.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['clarity'] = df.clarity.replace({"I1": 8, "SI2": 7, "SI1": 6, "VS2": 5, "VS1": 4, "VVS2": 3, "VVS1": 2, "IF": 1})    # from worst to best
#        carat  cut color  clarity  depth  table  price  length(mm)  width(mm)  \
# 0       0.23    2     E        7   61.5   55.0    326        3.95       3.98
# 1       0.21    1     E        6   59.8   61.0    326        3.89       3.84
# 2       0.23    4     E        4   56.9   65.0    327        4.05       4.07
# 3       0.29    1     I        5   62.4   58.0    334        4.20       4.23
# 4       0.31    4     J        7   63.3   58.0    335        4.34       4.35
# ...      ...  ...   ...      ...    ...    ...    ...         ...        ...
# 53935   0.72    2     D        6   60.8   57.0   2757        5.75       5.76
# 53936   0.72    4     D        6   63.1   55.0   2757        5.69       5.75
# 53937   0.70    3     D        6   62.8   60.0   2757        5.66       5.68
# 53938   0.86    1     H        7   61.0   58.0   2757        6.15       6.12
# 53939   0.75    2     D        7   62.2   55.0   2757        5.83       5.87
#
#        depth(mm)
# 0           2.43
# 1           2.31
# 2           2.31
# 3           2.63
# 4           2.75
# ...          ...
# 53935       3.50
# 53936       3.61
# 53937       3.56
# 53938       3.74
# 53939       3.64
#
# [53920 rows x 10 columns]

# %%
df["color"].value_counts()
# Out:
# color
# G    11284
# E     9797
# F     9538
# H     8298
# D     6774
# I     5421
# J     2808
# Name: count, dtype: int64

# %%
df["color"] = df.color.replace({"D": 1, "E": 2,"F": 3, "G": 4, "H": 5, "I": 6, "J": 7})
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3616\3063012480.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["color"] = df.color.replace({"D": 1, "E": 2,"F": 3, "G": 4, "H": 5, "I": 6, "J": 7})
#        carat  cut  color  clarity  depth  table  price  length(mm)  width(mm)  \
# 0       0.23    2      2        7   61.5   55.0    326        3.95       3.98
# 1       0.21    1      2        6   59.8   61.0    326        3.89       3.84
# 2       0.23    4      2        4   56.9   65.0    327        4.05       4.07
# 3       0.29    1      6        5   62.4   58.0    334        4.20       4.23
# 4       0.31    4      7        7   63.3   58.0    335        4.34       4.35
# ...      ...  ...    ...      ...    ...    ...    ...         ...        ...
# 53935   0.72    2      1        6   60.8   57.0   2757        5.75       5.76
# 53936   0.72    4      1        6   63.1   55.0   2757        5.69       5.75
# 53937   0.70    3      1        6   62.8   60.0   2757        5.66       5.68
# 53938   0.86    1      5        7   61.0   58.0   2757        6.15       6.12
# 53939   0.75    2      1        7   62.2   55.0   2757        5.83       5.87
#
#        depth(mm)
# 0           2.43
# 1           2.31
# 2           2.31
# 3           2.63
# 4           2.75
# ...          ...
# 53935       3.50
# 53936       3.61
# 53937       3.56
# 53938       3.74
# 53939       3.64
#
# [53920 rows x 10 columns]

# %%
import seaborn as sns

sns.lmplot(x="price", y="length(mm)",data=df, line_kws={'color': 'red'})
plt.grid()

# %%
sns.lmplot(x="price", y="width(mm)",data=df, line_kws={'color': 'red'})
plt.grid()

# %%
sns.lmplot(x="price", y="depth(mm)",data=df, line_kws={'color': 'red'})
plt.grid()

# %%
df.shape
# Out:
# (53920, 10)

# %%
sns.lmplot(x="price", y="depth",data=df, line_kws={'color': 'red'})
plt.grid()

# %%
#  removing outlier values in depth  
df = df[(df["depth"] < 75) & (df["depth"] > 50)]

# %%
sns.lmplot(x="price", y="table",data=df, line_kws={'color': 'red'})
plt.grid()

# %%
#  removing outlier values in table  
df = df[(df["depth"] < 80)]

# %%
# there are outliers in the price VS width and price VS depth

df = df[(df["width(mm)"]<15)]
df = df[(df["depth(mm)"]<10)]
df.shape
# Out:
# (53911, 10)

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price',
#        'length(mm)', 'width(mm)', 'depth(mm)'],
#       dtype='object')

# %%
features = df[['carat', 'cut', 'color', 'clarity', 'depth', 'table','length(mm)', 'width(mm)', 'depth(mm)']]
target = df[["price"]]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.33, random_state=5)

print(X_train.shape)
print(X_test.shape)
# Out:
# (36120, 9)
# (17791, 9)

# %%
from sklearn import linear_model

regressor = linear_model.LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.score(X_test, y_test)
# Out:
# 0.9072603565633661
